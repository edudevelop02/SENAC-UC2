# %% [markdown]
# # tratamento preliminar de dados para trabalho

# %%
import pandas as pd
import numpy  as np

df = 'funcionarios_naragroup_sujo.csv'
df = pd.read_csv(df, sep=';')
print(df.head())
# Out:
#    id               nome departamento        cargo     salario data_admissao  \
# 0  32    Roberto Cardoso   FINANCEIRO   Assistente    11605.79    04/09/2022
# 1  93       Amanda Silva   Financeiro  Coordenador     10032.2    09/08/2019
# 2  52    Jefferson Lima          T.I.   Estagiário     7387.84    2021-06-13
# 3  81      Aissa Pereira   Tecnologia     Analista    10376.08      Nov-2018
# 4   7     Patrícia Rocha   FINANCEIRO   Assistente  "14859,19"    2023-12-29
#
#                            email ativo
# 0  roberto.cardoso@naragroup.com     S
# 1     amanda.silva@naragroup.com     S
# 2   jefferson.lima@naragroup.com     1
# 3    aissa.pereira@naragroup.com  True
# 4   patrícia.rocha@naragroup.com   SIM

# %%
df.info()     # mostra o de dados e os tipos de cada coluna
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             100 non-null    int64
#  1   nome           100 non-null    str
#  2   departamento   100 non-null    str
#  3   cargo          100 non-null    str
#  4   salario        90 non-null     str
#  5   data_admissao  100 non-null    str
#  6   email          92 non-null     str
#  7   ativo          100 non-null    str
# dtypes: int64(1), str(7)
# memory usage: 6.4 KB

# %%
df.isnull() #
# Out:
#        id   nome  departamento  cargo  salario  data_admissao  email  ativo
# 0   False  False         False  False    False          False  False  False
# 1   False  False         False  False    False          False  False  False
# 2   False  False         False  False    False          False  False  False
# 3   False  False         False  False    False          False  False  False
# 4   False  False         False  False    False          False  False  False
# ..    ...    ...           ...    ...      ...            ...    ...    ...
# 95  False  False         False  False    False          False  False  False
# 96  False  False         False  False    False          False  False  False
# 97  False  False         False  False    False          False  False  False
# 98  False  False         False  False    False          False  False  False
# 99  False  False         False  False    False          False  False  False
#
# [100 rows x 8 columns]

# %%
df.isnull().sum()  # mostra o número de valores nulos em cada coluna
# Out:
# id                0
# nome              0
# departamento      0
# cargo             0
# salario          10
# data_admissao     0
# email             8
# ativo             0
# dtype: int64

# %%
df.isnull().sum().sum()  # mostra o número total de valores nulos no DataFrame
# Out:
# np.int64(18)

# %%
total_nulos = df.isnull().sum().sum()
print(f'\nTotal de nulos: {total_nulos}')
# Out:
# Total de nulos: 0

# %%
# Salvar shape antes
shape_antes = df.shape[0]

# Preencher salario nulo com a mediana se houver inconcistencia
mediana_salario = pd.to_numeric(df['salario'], errors='coerce').median()
df['salario'] = df['salario'].fillna(mediana_salario)

# Preencher email nulo com valor padrão
df['email'] = df['email'].fillna('sem_email')

print('Nulos restantes:')
print(df.isnull().sum())
# Out:
# Nulos restantes:
# id               0
# nome             0
# departamento     0
# cargo            0
# salario          0
# data_admissao    0
# email            0
# ativo            0
# dtype: int64

# %%
# Verificar quantas duplicatas existem
print(f'Duplicatas encontradas: {df.duplicated().sum()}')

# Visualizar as duplicatas
display(df[df.duplicated(keep=False)].sort_values('nome').head(20))
# Out:
# Duplicatas encontradas: 0
# Empty DataFrame
# Columns: [id, nome, departamento, cargo, salario, data_admissao, email, ativo]
# Index: []

# %%
# Remover duplicatas — manter a primeira ocorrência
df = df.drop_duplicates()

print(f'Shape após remover duplicatas: {df.shape}')
print(f'Registros removidos: {shape_antes - df.shape[0]}')
# Out:
# Shape após remover duplicatas: (100, 8)
# Registros removidos: 0

# %%
# Remover duplicatas — manter a primeira ocorrência
df = df.drop_duplicates()

print(f'Shape após remover duplicatas: {df.shape}')
print(f'Registros removidos: {shape_antes - df.shape[0]}')
# Out:
# Shape após remover duplicatas: (100, 8)
# Registros removidos: 0
